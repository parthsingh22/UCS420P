# %% [markdown]
# <a href="https://colab.research.google.com/github/parthsingh22/UCS420P/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assingment 1.1: WAP to print your name three times

# %%
print("parth")
print("parth")
print("parth")
# Out:
# parth
# parth
# parth

# %% [markdown]
# Assingment 2.1: WAP to add three numbers and print the result.

# %%
a=7
b=5
c=8
d=a+b+c
print(a,"+",b,"+",c,"=",d)
# Out:
# 7 + 5 + 8 = 20

# %% [markdown]
# Assingment 2.2: WAP to concatinate three strings and print the result.

# %%
a="james"
b="bond"
c="007"
d=a+b+c
print(d)
# Out:
# jamesbond007

# %% [markdown]
# Assingment 4.1: WAP to print the table of 7, 9.

# %%
for i in range(1,11):
  print(f"7 x {i} = {7*i}")
# Out:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %%
for i in range(1,11):
  print(f"9 x {i} = {9*i}")
# Out:
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %% [markdown]
# Assingment 4.2: WAP to print the table of n and n is given by user.

# %%
n=int(input("Enter any no:"))
for i in range(1,11):
  print(f"{n} x {i} = {n*i}")
# Out:
# Enter any no:8
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80

# %% [markdown]
# Assingment 4.3: WAP to add all the numbers from 1 to n and n is given by user.

# %%
n=int(input("Enter any no:"))
sum=0
for i in range(1,n+1):
  sum=sum+i
print(sum)
# Out:
# Enter any no:10
# 55

# %% [markdown]
# Assingment 5.1: WAP to find max amoung three numbers and input from user.

# %%
a=int(input("enter 1st no:"))
b=int(input("enter 2nd no:"))
c=int(input("enter 3rd no:"))
print(max(a,b,c))
# Out:
# enter 1st no:5
# enter 2nd no:7
# enter 3rd no:9
# 9

# %% [markdown]
# Assingment 5.2: WAP to add all numbers divisible by 7 and 9 from 1 to n and n is given by the user.

# %%
n=int(input("enter any no:"))
s=0
for i in range(1,n+1):
  if i%7==0 and i%9 ==0:
    s=s+i
print("the sum of the numbers is:",s)
# Out:
# enter any no:64
# the sum of the numbers is: 63

# %% [markdown]
# Assingment 5.3: WAP to add all prime numbers from 1 to n and n is given by the user.

# %%
n=int(input("enter any no:"))
s=0
for i in range(2,n+1):
  prime=True

  for j in range(2,i):
    if(i%j==0):
      prime=False
      break
  if prime:
    s+=i
print(s)
# Out:
# enter any no:50
# 328

# %% [markdown]
# Assingment 6.1: WAP using function that add all odd numbers from 1 to n, n is given by the user.

# %%
def add_odd(n):
  s=0
  for i in range(1,n+1,2):
    s+=i
  return s
A=add_odd(10)
print(A)
# Out:
# 25

# %% [markdown]
# Assingment 6.2: WAP using function that add all prime numbers from 1 to n, n given by the user.

# %%
def Add_prime(n):
    sum=0
    for i in range(2, n+1):
        flag=0
        for div in range(2, int(i**0.5)+1):
            if(i%div==0):
                flag=1
                break
        if(flag==0):
            sum+=i
    return sum
result = Add_prime(50)
print(result)
# Out:
# 328
